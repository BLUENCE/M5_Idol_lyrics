# %%
import pandas as pd

# %%
# 곡 정보 파일 불러오기
df = pd.read_csv('../Data/song_data_yoon_ver06.csv')

# %%
# 가수 정보 파일 불러오기
df2 = pd.read_csv('../Data/idol_list.csv', encoding='euc-kr')

# %%
# 곡 정보와 가수 정보를 머지해준다.
song = pd.merge(df, df2, on='artist')

# %%
# 가사 분석에 용이하도록 <br>을 공백으로 바꿔준다.
song['lyrics'] = song['lyrics'].str.replace(r'<br>', ' ')

# %%
# 전체 곡의 장르를 살펴본다.
song.song_genre.value_counts()
# Out:
# Dance                      5363
# Ballad                     2249
# Rap / Hip-hop               588
# Rock                        494
# R&B / Soul                  402
# Drama                       194
# Electronica                  39
# 기타                           39
# Drama,Dance                  27
# Drama,Ballad                 25
# Pop                          24
# Animation                    24
# Korean Movie                 12
# Folk                         10
# Musical                       8
# Drama,Rock                    6
# Game                          5
# 동요                            4
# Korean Movie,Ballad           3
# Adult Contemporary            2
# Drama,Rap / Hip-hop           2
# Animation,Dance               2
# Jazz                          1
# Korean Movie,Rock             1
# 국내CCM                         1
# Ballad,Rap / Hip-hop          1
# Animation,Rock                1
# Drama,Folk                    1
# Electronica,Dance             1
# ...

# %%
female = song[song['gender'] == '여']

# %%
# 여자아이돌 곡의 장르를 살펴본다.
genre_f = female.song_genre.value_counts()
genre_f
# Out:
# Dance                      2195
# Ballad                      704
# R&B / Soul                   96
# Drama                        91
# Rap / Hip-hop                55
# Electronica                  23
# Rock                         22
# 기타                           17
# Animation                    13
# Drama,Dance                  11
# Drama,Ballad                  9
# Pop                           5
# 동요                            4
# Game                          3
# Korean Movie                  3
# Folk                          2
# Jazz                          1
# Drama,Rock                    1
# Blues                         1
# Korean Movie,R&B / Soul       1
# Electronica,Dance             1
# -                             1
# Ballad,Rap / Hip-hop          1
# Adult Contemporary            1
# Korean Movie,Ballad           1
# Animation,Dance               1
# Korean Traditional            1
# Name: song_genre, dtype: int64

# %%
female['song_genre'].shape
# Out:
# (3264,)

# %%
male = song[song['gender'] == '남']

# %%
female_k = female[female['lyrics'].str.contains("", na=False)]
female_k['lyrics'].tolist()

# %%
female_k = female[female['lyrics'].str.contains("사춘기", na=False)]
female_k['lyrics'].tolist()
# Out:
# ["Knock Knock 낯선 너의 등장이 평소답지 않은 눈빛이 뭔가 느낌이 좀 수상해 지금은 12시10분전 점점 분위기에 취하고 눈빛은 서로를 비추고 흐르는 침묵도 끈적해 터질 것만 같은 우리 사이 너와나 입을 맞춰 I feel good 너에게 나를 맡겨 I feel good 이건 좀 위험해 위험해 위험해 나 선을 넘을 것만 같아 너와나 같이 그린 I feel good 오렌지 빛깔 그림 I feel good 조금은 위험해 위험해 위험해도 멈출 수가 없어 나 I feel good Knock Knock 그때 예상했었지 여잔 촉이 정말 빠르지 이미 물은 엎질러졌어 우린 몰래 새벽을 맞네 At that time Knock Knock 지난 여름부터 밤낮 사춘기 소녀처럼 꿈꾸게 만들었어 로맨스 오늘만 기다렸어 Oh Yes Oh 핸드폰은 Off 치명적인 호흡 비밀스런 파티 깔아 레드 카펫 내 공간에 와준 널 환영해 Knock Knock Knock Knock 두 손을 머리위로 Clap your hands 너와나 입을 맞춰 I feel good 너에게 나를 맡겨 I feel good 이건 좀 위험해 위험해 위험해 나 선을 넘을 것만 같아 너와나 같이 그린 I feel good 오렌지 빛깔 그림 I feel good 조금은 위험해 위험해 위험해도 멈출 수가 없어 나 I feel good 나를 깨우는 너의 속삭임 I feel good 너의 손짓 또 몸짓 I feel good 너와 단둘이 맞은 아침이 I feel good I feel good good good good 헝클어진 머리 헐크 같은 바디 라인 보고 싶어 백허그까지 너 uh 고개를 끄덕 끄덕 숨 쉴 수가 없네 I can't control my self 준비했어 널 위해 MAMAMOO is coming back for you Knock Knock Knock Knock 두 손을 머리 위로 Clap your hands 너와나 입을 맞춰 I feel good 너에게 나를 맡겨 I feel good 이건 좀 위험해 위험해 위
# ...

# %%
male_k = male[male['lyrics'].str.contains("사춘기", na=False)]
male_k['lyrics'].tolist()
# Out:
# ["우리 마음속 깊은 곳에 언제나 남아있는 그리운 지난날 다시 되돌릴 수는 없는 그때를 이제 다시 또 함께 시작해 함께 한 시간들 또 함께 했던 아픔들 속에 싹트던 우정을 여기 다시 만들꺼라 생각해 오랫동안 함께 한 추억만 또 여기까지 한 지금 이 순간처럼만 계속된 우리의 음악과 솟구치던 꿈과 아낌없던 나무같던 너와 지하철 속에서 길거리에서 교실에서 듣던 많은 CD들과 Headphone 힘들을 때 내게 기대 쉬었었네 추억의 Rap 속엔 WU TANG CLAN 사춘기의 나이 어른이 된 나이 한살 두살 지나가 이렇게 변한 나이 yeah 여기까지 왔네 변치않네 깊게 굳게 믿네 Come on 우리 마음속 깊은 곳에 언제나 남아있는 그리운 지난날 다시 되돌릴 수는 없는 그때를 이제 다시 또 함께 시작해 1 2 3 3 2 1 모든걸 주었던 빼앗아 갔던 많은 일들 꿈같았던 지난 날들 어제 같이 느껴지는 어릴 적 시절 다시 돌릴 수는 없는 우리들의 그 소설 어데로 갔는지 다시 찾는지 Hip Hop Classic RUN D M C EPMD HEAVY D PUBLIC ENEMY N W A LL COOL J EAST COAST & KRIS KROSS TRIBE CALLED QUEST PETE ROCK & WESTSIDE SOLDIER 2PAC 여기 맘속에 모두 살아있네 가슴속 깊이 희망의 메아리치네 We just wanna party's Goin' on The good time come on 우리 마음속 깊은 곳에 언제나 남아있는 그리운 지난날 다시 되돌릴 수는 없는 그때를 이제 다시 또 함께 시작해  함께 한 시간들 또 함께 했던 아픔들 속에 싹트던 우정을 여기 다시 만들꺼라 생각해 우리가 시작할 때 랩에 폭삭 빠져있던 그때의 공기에 다시 홀짝 돌아가고 싶은 나의 이 맘 너의 작은 소망 우리들의 갈망 속에 희망 누구나 한번 떠올리네 아무 것도 모를 시절 그리워해 내 생애 있어 가장 행복할 때 그 속에 거기 내 모습이 있네 사춘기의 나이 어른이 된 나이 한살 두살 지나가 이렇
# ...

# %%
male_k = male[male['lyrics'].str.contains("", na=False)]
male_k['lyrics'].tolist()

# %%
female_k = female[female['lyrics'].str.contains("엄마", na=False)]
female_k.shape
# Out:
# (49, 17)

# %%
male_k = male[male['lyrics'].str.contains("아빠", na=False)]
male_k.shape
# Out:
# (37, 17)

# %%
female_k = female[female['lyrics'].str.contains("어머니", na=False)]
female_k.shape

# %%
male_k = male[male['lyrics'].str.contains("아버지", na=False)]
male_k.shape

# %%
female['song_genre'].apply(pd.value_counts).plot(kind='pie', layout=(3264,1), subplots=True)

# %%
female['song_genre'].value_counts()[:20].plot(kind='barh')

# %%
# 남자아이돌 곡의 장르를 살펴본다.
male.song_genre.value_counts()

# %%
# 여자아이돌 곡의 가사 중 '(키스|Kiss|chu)'가 등장하는 곡 수는?
female_k = female[female['lyrics'].str.contains("(키스|Kiss|chu)", na=False)]
female_k.shape

# %%
# 남자아이돌 곡의 가사 중 '(키스|Kiss|chu)'가 등장하는 곡 수는?
male_k = male[male['lyrics'].str.contains("(키스|Kiss|chu)", na=False)]
male_k.shape
# Out:
# /Users/yunkim/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
# (163, 17)

# %%
# 여자아이돌 곡의 가사 중 '(섹시|Sexy)'가 등장하는 곡 수는?
female_s = female[female['lyrics'].str.contains("(섹시|Sexy)", na=False)]
female_s.shape
# Out:
# /Users/yunkim/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
# (67, 17)

# %%
# 남자아이돌 곡의 가사 중 '(섹시|Sexy)'가 등장하는 곡 수는?
male_s = male[male['lyrics'].str.contains("(섹시|Sexy)", na=False)]
male_s.shape
# Out:
# /Users/yunkim/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
# (84, 17)

# %%
# 여자아이돌 곡의 가사 중 '(큐트|Cute|큐티)'가 등장하는 곡 수는?
female_c = female[female['lyrics'].str.contains("(큐트|Cute|큐티)", na=False)]
female_c.shape
# Out:
# /Users/yunkim/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
# (0, 17)

# %%
# 남자아이돌 곡의 가사 중 '(큐트|Cute|큐티)'가 등장하는 곡 수는?
male_c = male[male['lyrics'].str.contains("(큐트|Cute|큐티)", na=False)]
male_c.shape
# Out:
# /Users/yunkim/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
# (3, 17)

# %%
# 여자아이돌 곡의 가사 중 '(귀여|귀엽)'이  등장하는 곡 수는?
female_c = female[female['lyrics'].str.contains("(귀여|귀엽)", na=False)]
female_c.shape
# Out:
# /Users/yunkim/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
# (73, 17)

# %%
# 남자아이돌 곡의 가사 중 '(귀여|귀엽)'이 등장하는 곡 수는?
male_c = male[male['lyrics'].str.contains("(귀여|귀엽)", na=False)]
male_c.shape
# Out:
# /Users/yunkim/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
# (95, 17)

# %%
# 여자아이돌 곡의 가사 중 '(원해|원하다)'가 등장하는 곡 수는?
female_c = female[female['lyrics'].str.contains("(원해|원하다)", na=False)]
female_c.shape
# Out:
# /Users/yunkim/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
# (205, 17)

# %%
# 남자아이돌 곡의 가사 중 '(원해|원하다)'가 등장하는 곡 수는?
male_c = male[male['lyrics'].str.contains("(원해|원하다)", na=False)]
male_c.shape
# Out:
# /Users/yunkim/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
# (412, 17)

# %%
# 여자아이돌 곡의 가사 중 '하지마|그러지마'가 등장하는 곡 수는?
female_k = female[female['lyrics'].str.contains("(하지마|그러지마)", na=False)]
female_k.shape
# Out:
# /Users/yunkim/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
# (264, 17)

# %%
# 남자아이돌 곡의 가사 중 '하지마'가 등장하는 곡 수는?
male_k = male[male['lyrics'].str.contains("(하지마|그러지마)", na=False)]
male_k.shape
# Out:
# /Users/yunkim/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
# (459, 17)

# %%
# 여자아이돌 곡의 가사 중 '가지마'가 등장하는 곡 수는?
female_k = female[female['lyrics'].str.contains("가지마", na=False)]
female_k.shape
# Out:
# (54, 17)

# %%
# 남자아이돌 곡의 가사 중 '가지마'가 등장하는 곡 수는?
male_k = male[male['lyrics'].str.contains("가지마", na=False)]
male_k.shape
# Out:
# (130, 17)

# %%
# 여자아이돌 곡의 가사 중 '미래'가 등장하는 곡 수는?
female_k = female[female['lyrics'].str.contains("미래", na=False)]
female_k.shape
# Out:
# (77, 17)

# %%
# 남자아이돌 곡의 가사 중 '미래'가 등장하는 곡 수는?
male_k = male[male['lyrics'].str.contains("미래", na=False)]
male_k.shape
# Out:
# (255, 17)

# %%
female_k = female[female['lyrics'].str.contains("인생", na=False)]
female_k.shape
# Out:
# (46, 17)

# %%
male_k = male[male['lyrics'].str.contains("인생", na=False)]
male_k.shape
# Out:
# (244, 17)

# %%
female_k = female[female['lyrics'].str.contains("현실", na=False)]
female_k.shape
# Out:
# (62, 17)

# %%
male_k = male[male['lyrics'].str.contains("현실", na=False)]
male_k.shape
# Out:
# (262, 17)

# %%
female_k = female[female['lyrics'].str.contains("돈", na=False)]
female_k.shape
# Out:
# (36, 17)

# %%
male_k = male[male['lyrics'].str.contains("돈", na=False)]
male_k.shape
# Out:
# (178, 17)

# %%
female_k = female[female['lyrics'].str.contains("일생", na=False)]
female_k.shape
# Out:
# (4, 17)

# %%
male_k = male[male['lyrics'].str.contains("일생", na=False)]
male_k.shape
# Out:
# (18, 17)

# %%
female_k = female[female['lyrics'].str.contains("삶", na=False)]
female_k.shape
# Out:
# (83, 17)

# %%
male_k = male[male['lyrics'].str.contains("삶", na=False)]
male_k.shape
# Out:
# (442, 17)

# %%
female_k = female[female['lyrics'].str.contains("일상", na=False)]
female_k.shape
# Out:
# (31, 17)

# %%
male_k = male[male['lyrics'].str.contains("일상", na=False)]
male_k.shape
# Out:
# (83, 17)

# %%
female_k = female[female['lyrics'].str.contains("죽음", na=False)]
female_k.shape
# Out:
# (5, 17)

# %%
male_k = male[male['lyrics'].str.contains("죽음", na=False)]
male_k.shape
# Out:
# (24, 17)

# %%
female_k = female[female['lyrics'].str.contains("월급", na=False)]
female_k.shape
# Out:
# (0, 17)

# %%
male_k = male[male['lyrics'].str.contains("월급", na=False)]
male_k.shape
# Out:
# (4, 17)

# %%
female_k = female[female['lyrics'].str.contains("가난", na=False)]
female_k.shape
# Out:
# (6, 17)

# %%
male_k = male[male['lyrics'].str.contains("가난", na=False)]
male_k.shape
# Out:
# (19, 17)

# %%
female_k = female[female['lyrics'].str.contains("어른", na=False)]
female_k.shape
# Out:
# (39, 17)

# %%
male_k = male[male['lyrics'].str.contains("어른", na=False)]
male_k.shape
# Out:
# (94, 17)

# %%
female_k = female[female['lyrics'].str.contains("도전", na=False)]
female_k.shape
# Out:
# (6, 17)

# %%
male_k = male[male['lyrics'].str.contains("도전", na=False)]
male_k.shape
# Out:
# (30, 17)

# %%
female_k = female[female['lyrics'].str.contains("성장", na=False)]
female_k.shape
# Out:
# (1, 17)

# %%
male_k = male[male['lyrics'].str.contains("성장", na=False)]
male_k.shape
# Out:
# (8, 17)

# %%
female_k = female[female['lyrics'].str.contains("young", na=False)]
female_k.shape
# Out:
# (9, 17)

# %%
male_k = male[male['lyrics'].str.contains("young", na=False)]
male_k.shape
# Out:
# (26, 17)

# %%
female_k = female[female['lyrics'].str.contains("청춘", na=False)]
female_k.shape
# Out:
# (2, 17)

# %%
male_k = male[male['lyrics'].str.contains("청춘", na=False)]
male_k.shape
# Out:
# (29, 17)

# %%
female_k = female[female['lyrics'].str.contains("(젊은|젊어)", na=False)]
female_k.shape
# Out:
# /Users/yunkim/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   """Entry point for launching an IPython kernel.
# (6, 17)

# %%
male_k = male[male['lyrics'].str.contains("(젊은|젊어)", na=False)]
male_k.shape
# Out:
# /Users/yunkim/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   """Entry point for launching an IPython kernel.
# (37, 17)

# %%
female_k = female[female['lyrics'].str.contains("기회", na=False)]
female_k.shape
# Out:
# (67, 17)

# %%
male_k = male[male['lyrics'].str.contains("기회", na=False)]
male_k.shape
# Out:
# (157, 17)

# %%
female_k = female[female['lyrics'].str.contains("달려", na=False)]
female_k.shape
# Out:
# (194, 17)

# %%
male_k = male[male['lyrics'].str.contains("달려", na=False)]
male_k.shape
# Out:
# (495, 17)

# %%
female_k = female[female['lyrics'].str.contains("뛰어", na=False)]
female_k.shape
# Out:
# (109, 17)

# %%
male_k = male[male['lyrics'].str.contains("뛰어", na=False)]
male_k.shape
# Out:
# (240, 17)

# %%
female_k = female[female['lyrics'].str.contains("다음", na=False)]
female_k.shape
# Out:
# (63, 17)

# %%
male_k = male[male['lyrics'].str.contains("다음", na=False)]
male_k.shape
# Out:
# (152, 17)

# %%
female_k = female[female['lyrics'].str.contains("성공", na=False)]
female_k.shape
# Out:
# (10, 17)

# %%
male_k = male[male['lyrics'].str.contains("성공", na=False)]
male_k.shape
# Out:
# (51, 17)

# %%
female_k = female[female['lyrics'].str.contains("실패", na=False)]
female_k.shape
# Out:
# (11, 17)

# %%
male_k = male[male['lyrics'].str.contains("실패", na=False)]
male_k.shape
# Out:
# (49, 17)

# %%
female_k = female[female['lyrics'].str.contains("땀", na=False)]
female_k.shape
# Out:
# (38, 17)

# %%
male_k = male[male['lyrics'].str.contains("땀", na=False)]
male_k.shape
# Out:
# (101, 17)

# %%
female_k = female[female['lyrics'].str.contains("심장", na=False)]
female_k.shape
# Out:
# (273, 17)

# %%
male_k = male[male['lyrics'].str.contains("심장", na=False)]
male_k.shape
# Out:
# (628, 17)

# %%
female_k = female[female['lyrics'].str.contains("위험", na=False)]
female_k.shape
# Out:
# (56, 17)

# %%
male_k = male[male['lyrics'].str.contains("위험", na=False)]
male_k.shape
# Out:
# (146, 17)

# %%
female_k = female[female['lyrics'].str.contains("조심스럽게", na=False)]
female_k.shape
# Out:
# (24, 17)

# %%
male_k = male[male['lyrics'].str.contains("조심스럽게", na=False)]
male_k.shape
# Out:
# (27, 17)

# %%
female_k = female[female['lyrics'].str.contains("봐줘", na=False)]
female_k.shape
# Out:
# (73, 17)

# %%
male_k = male[male['lyrics'].str.contains("봐줘", na=False)]
male_k.shape
# Out:
# (104, 17)

# %%
female_k = female[female['lyrics'].str.contains("(멋져|멋진|멋있)", na=False)]
female_k.shape
# Out:
# /Users/yunkim/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   """Entry point for launching an IPython kernel.
# (216, 17)

# %%
male_k = male[male['lyrics'].str.contains("(멋져|멋진|멋있)", na=False)]
male_k.shape
# Out:
# /Users/yunkim/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   """Entry point for launching an IPython kernel.
# (230, 17)

# %%
female_k = female[female['lyrics'].str.contains("잘생", na=False)]
female_k.shape
# Out:
# (13, 17)

# %%
male_k = male[male['lyrics'].str.contains("잘생", na=False)]
male_k.shape
# Out:
# (14, 17)

# %%
female_k = female[female['lyrics'].str.contains("(예쁜|예뻐|예쁘)", na=False)]
female_k.shape
# Out:
# /Users/yunkim/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   """Entry point for launching an IPython kernel.
# (309, 17)

# %%
female_k = female[female['lyrics'].str.contains("(날씬|뚱뚱)", na=False)]
female_k.shape
# Out:
# /Users/yunkim/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   """Entry point for launching an IPython kernel.
# (7, 17)

# %%
male_k = male[male['lyrics'].str.contains("(날씬|뚱뚱)", na=False)]
male_k.shape
# Out:
# /Users/yunkim/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   """Entry point for launching an IPython kernel.
# (4, 17)

# %%
male_k = male[male['lyrics'].str.contains("(예쁜|예뻐|예쁘)", na=False)]
male_k.shape
# Out:
# /Users/yunkim/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   """Entry point for launching an IPython kernel.
# (585, 17)

# %%
female_k = female[female['lyrics'].str.contains("아름다", na=False)]
female_k.shape
# Out:
# (196, 17)

# %%
male_k = male[male['lyrics'].str.contains("아름다", na=False)]
male_k.shape
# Out:
# (691, 17)

# %%
female_k = female[female['lyrics'].str.contains("언니", na=False)]
female_k.shape
# Out:
# (41, 17)

# %%
female_k = female[female['lyrics'].str.contains("여자", na=False)]
female_k.shape
# Out:
# (372, 17)

# %%
female_k = female[female['lyrics'].str.contains("남자", na=False)]
female_k.shape
# Out:
# (405, 17)

# %%
male_k = male[male['lyrics'].str.contains("남자", na=False)]
male_k.shape
# Out:
# (683, 17)

# %%
male_k = male[male['lyrics'].str.contains("여자", na=False)]
male_k.shape
# Out:
# (573, 17)

# %%
female_k = female[female['lyrics'].str.contains("형", na=False)]
female_k.shape
# Out:
# (55, 17)

# %%
male_k = male[male['lyrics'].str.contains("언니", na=False)]
male_k.shape
# Out:
# (8, 17)

# %%
male_k = male[male['lyrics'].str.contains("형", na=False)]
male_k.shape
# Out:
# (178, 17)

# %%
female_k = female[female['lyrics'].str.contains("아이", na=False)]
female_k.shape
# Out:
# (221, 17)

# %%
male_k = male[male['lyrics'].str.contains("아이", na=False)]
male_k.shape
# Out:
# (286, 17)

# %%
female_k = female[female['lyrics'].str.contains("순수", na=False)]
female_k.shape
# Out:
# (34, 17)

# %%
male_k = male[male['lyrics'].str.contains("순수", na=False)]
male_k.shape
# Out:
# (99, 17)

# %%
female_k = female[female['lyrics'].str.contains("확신", na=False)]
female_k.shape
# Out:
# (15, 17)

# %%
male_k = male[male['lyrics'].str.contains("확신", na=False)]
male_k.shape
# Out:
# (40, 17)

# %%
female_k = female[female['lyrics'].str.contains("열정", na=False)]
female_k.shape
# Out:
# (21, 17)

# %%
male_k = male[male['lyrics'].str.contains("열정", na=False)]
male_k.shape
# Out:
# (58, 17)

# %%
female_k = female[female['lyrics'].str.contains("상상", na=False)]
female_k.shape
# Out:
# (207, 17)

# %%
male_k = male[male['lyrics'].str.contains("상상", na=False)]
male_k.shape
# Out:
# (300, 17)

# %%
female_k = female[female['lyrics'].str.contains("동화", na=False)]
female_k.shape
# Out:
# (40, 17)

# %%
male_k = male[male['lyrics'].str.contains("동화", na=False)]
male_k.shape
# Out:
# (62, 17)

# %%
female_k = female[female['lyrics'].str.contains("홀로", na=False)]
female_k.shape
# Out:
# (59, 17)

# %%
male_k = male[male['lyrics'].str.contains("홀로", na=False)]
male_k.shape
# Out:
# (218, 17)

# %%
female_k = female[female['lyrics'].str.contains(r"\b술", na=False)]
female_k.shape
# Out:
# (53, 17)

# %%
male_k = male[male['lyrics'].str.contains(r"\b술", na=False)]
male_k.shape
# Out:
# (209, 17)

# %%
female_k = female[female['lyrics'].str.contains("담배", na=False)]
female_k.shape
# Out:
# (6, 17)

# %%
male_k = male[male['lyrics'].str.contains("담배", na=False)]
male_k.shape
# Out:
# (44, 17)

# %%
# 정규표현식 어떻게 써야 할지?
female_k = female[female['lyrics'].str.contains(r"\b야\b", na=False)]
female_k.shape
# Out:
# (35, 17)

# %%
male_k = male[male['lyrics'].str.contains(r"\b야\b", na=False)]
male_k.shape
# Out:
# (88, 17)

# %%
from collections import Counter
from sklearn.manifold import TSNE
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer

# %%
female_l = female.lyrics.tolist()

# %%
tfidf = TfidfVectorizer(max_features = 100, max_df=0.95, min_df=0)

#generate tf-idf term-document matrix
A_tfidf_sp = tfidf.fit_transform(female_l)  #size D x V

# %%
#tf-idf dictionary    
tfidf_dict = tfidf.get_feature_names()
print(tfidf_dict)
# Out:
# ['ah', 'all', 'and', 'baby', 'be', 'boy', 'can', 'come', 'do', 'don', 'eh', 'for', 'get', 'girl', 'go', 'good', 'hey', 'in', 'is', 'it', 'just', 'know', 'la', 'let', 'like', 'love', 'me', 'my', 'na', 'no', 'now', 'oh', 'on', 'one', 'ooh', 'say', 'so', 'that', 'the', 'to', 'uh', 'up', 'wanna', 'want', 'we', 'what', 'woo', 'yeah', 'you', 'your', '같아', '같은', '거야', '그대', '그렇게', '나는', '나도', '나를', '나의', '내가', '내게', '너는', '너를', '너만', '너무', '너에게', '너와', '너의', '네가', '니가', '다가와', '다른', '다시', '맘을', '매일', '모두', '모든', '몰라', '보고', '사랑', '사랑을', '사랑해', '속에', '싶어', '않아', '없는', '없어', '오늘', '우리', '이런', '이렇게', '이제', '이젠', '있는', '있어', '자꾸', '정말', '좋아', '지금', '함께']

# %%
data_array = A_tfidf_sp.toarray()
data = pd.DataFrame(data_array, columns=tfidf_dict)
data.shape
# Out:
# (3264, 100)

# %% [markdown]
# TF-IDF score Top 100 단어 시각화
#
# TF-IDF를 사용하여 단어의 중요도를 산출하였고, 선택된 100개의 단어를 t-SNE로 시각화 하였다. t-SNE는 고차원(본 예제에서는 100차원)상에 존재하는 데이터의 유사성들을 KL-divergence가 최소화되도록 저차원(2차원)으로 임베딩시키는 방법이다.

# %%
tsne = TSNE(n_components=2, n_iter=10000, verbose=1)

# %%
data_array.shape
# Out:
# (3264, 100)

# %%
data_array.T.shape
# Out:
# (100, 3264)

# %%
Z = tsne.fit_transform(data_array.T)
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 100 samples in 0.001s...
# [t-SNE] Computed neighbors for 100 samples in 0.306s...
# [t-SNE] Computed conditional probabilities for sample 100 / 100
# [t-SNE] Mean sigma: 1.755262
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 103.515900
# [t-SNE] Error after 4400 iterations: 0.601937

# %%
print(Z[0:5])
print('Top words: ',len(Z))
# Out:
# [[30.318787   6.880713 ]
#  [28.250284   4.5858264]
#  [27.98469    5.0529723]
#  [29.439741   7.533298 ]
#  [28.080845   6.1582956]]
# Top words:  100

# %%
import matplotlib.font_manager as fm
import matplotlib.pyplot as plt
from collections import Counter

# %%
path = '/users/yunkim/Library/Fonts/KoPubBatang_Pro+Bold.otf'
fontprop = fm.FontProperties(fname=path, size=8)
plt.scatter(Z[:,0], Z[:,1])
for i in range(len(tfidf_dict)):
    plt.annotate(s=tfidf_dict[i].encode("utf8").decode("utf8"), xy=(Z[i,0], Z[i,1]),fontProperties =fontprop)

plt.draw()

# %% [markdown]
# analogies란 단어들 사이에 관계를 추론하는 것으로, 본예제에서 (‘lg’, ‘삼성’) 이라는 단어 벡터가 있을 때 tv와 어떤 단어가 같은 방향벡터를 가지는지 확인해 볼 수 있다. 구체적으로, em을 TF-IDF 100차원으로 임베딩시키는 함수라고 생각해 보면, em['lg'] + em['삼성'] - em['tv'] = 특정 벡터값을 구할 수 있다. 그 벡터값과 유사한 단어를 찾기 위해 모든 단어들과의 유사성(L2-norm, Cosine distance)을 구한 후 가장 유사한 단어를 뽑는 것이 아래의 코드 내용이다.

# %%
male_l = male.lyrics.tolist()
male_l
# Out:
# ['갈수 없는 곳이란 우리에겐 없어 보이는 길밖에도 세상은 있어 언제나 식지않는 마음이 있어 자유로운 내뜻을 막을순 없어 Taiji Boys 언제나 영원히 Taiji Boys 더 넓은 세상이 Taiji Boys 우리의 마음이 Taiji Boys 하나가 돼  무심코 던진 돌에 개구리는 죽어 우리가 사는 이유를 알고 싶었어 Taiji Boys 언제나 영원히 Taiji Boys 더 넓은 세상이 Taiji Boys 우리의 마음이 Taiji Boys 하나가 돼',
#  '항상 난 지나치기만 했네 이젠 난 미련없이 끝내 됐어 찾아냈어 난 모두가 또 나를 원하는가 이젠 난 바라는건 없어 나는 ROCK and RADIO and D A T 나의 기타 BIG ENERGY 나의 장갑속의 너의 큰 반지 눈부신 햇살에 내 모든 것을 맡기고 오래된 그리움은 모두 벗어 제끼고 나의 그 생각들엔 멋진 날개를 달아 이제는 난 지치지 않아 모든걸 난 여태 이겨내왔어 밤새워 내린 하얀눈과 아침을 열어주고 있는 태양 내 맘을 자극하는 바람 난 지금 시작해 KNOCK THE WORLD BREAK THE WALL ROCK and ROLL 하얗게 내린 눈 위로 날아가듯 내 꿈에 큰 날개를 달고서 더 밝은 나의 미래를 약속하듯 세상은 눈부시게 빛나고 있어  길을 떠나며 난 많은 사람들을 지나쳤지 내게는 없던 또 다른 눈빛 시간을 겁내지 말고 이제는 막연히 기다릴수는 없어 오래된 ORGAN소리 하늘을 걸어다니는 다리 눈부신 햇살에 내 모든 것을 맡기고 오래된 그리움은 모두 벗어 제끼고 나의 그 생각들엔 멋진 날개를 달아 이제는 난 지치지 않아 모든걸 난 여태 이겨내왔어 밤새워 내린 하얀눈과 아침을 열어주고 있는 태양 내 맘을 자극하는 바람 난 지금 시작해 KNOCK THE WORLD BREAK THE WALL ROCK and ROLL 하얗게 내린 눈 위로 날아가듯 내 꿈에 큰 날개를 달고서 더 밝은 나의 미래를 약속하듯 세상은 눈부시게 빛나고 있어',
# ...

# %%
male_all = sum(male_l, [])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-fa9ec9e551c5> in <module>()
# ----> 1 male_all = sum(male_l, [])
#
# TypeError: can only concatenate list (not "str") to list

# %%
tfidf = TfidfVectorizer(max_features = 500, max_df=0.95, min_df=0)

#generate tf-idf term-document matrix
A_tfidf_sp = tfidf.fit_transform(male_l)  #size D x V

# %%
#tf-idf dictionary    
tfidf_dict = tfidf.get_feature_names()
print(tfidf_dict)
# Out:
# ['about', 'again', 'ah', 'all', 'alright', 'always', 'and', 'are', 'at', 'away', 'babe', 'baby', 'back', 'bad', 'bang', 'be', 'beautiful', 'better', 'body', 'boom', 'bounce', 'boy', 'break', 'but', 'by', 'bye', 'can', 'cause', 'come', 'crazy', 'cry', 'dance', 'day', 'do', 'don', 'down', 'eh', 'every', 'everybody', 'everyday', 'everything', 'feel', 'fly', 'for', 'forever', 'get', 'girl', 'give', 'go', 'god', 'going', 'gonna', 'good', 'goodbye', 'got', 'gotta', 'ha', 'hands', 'have', 'heart', 'hello', 'here', 'hey', 'high', 'hold', 'hoo', 'hot', 'how', 'if', 'in', 'is', 'it', 'just', 'keep', 'know', 'la', 'lady', 'let', 'life', 'light', 'like', 'll', 'look', 'love', 'luv', 'ma', 'make', 'man', 'me', 'mind', 'more', 'my', 'na', 'need', 'never', 'night', 'no', 'not', 'now', 'of', 'oh', 'ok', 'on', 'one', 'only', 'ooh', 'out', 'over', 'party', 'please', 'put', 're', 'ready', 'right', 'rock', 'run', 'say', 'see', 'shake', 'she', 'show', 'so', 'sorry', 'star', 'stay', 'step', 'still', 'stop
# ...
