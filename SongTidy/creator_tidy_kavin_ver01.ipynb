# %%
from urllib import request
import pandas as pd
import numpy as np
import requests
import re
import csv

# %%
path = "C:/Users/Kavin/Projects/M5_Idol_lyrics/Data/song_data_end.csv" # 불러올 경로설정
song = pd.read_csv(path, encoding = 'utf-8')
song = song.drop(columns=['Unnamed: 0'])

# %%
song
# Out:
#                                   title    artist  \
# 0                                태지 보이스  서태지와 아이들
# 1                            시대유감(時代遺憾)  서태지와 아이들
# 2                              수시아(誰是我)  서태지와 아이들
# 3                   이 밤이 깊어 가지만 (Remix)  서태지와 아이들
# 4                            Free Style  서태지와 아이들
# 5                                 난 알아요  서태지와 아이들
# 6                          너와 함께한 시간속에서  서태지와 아이들
# 7                               환상속의 그대  서태지와 아이들
# 8                                   하여가  서태지와 아이들
# 9                                   너에게  서태지와 아이들
# 10                             우리들만의 추억  서태지와 아이들
# 11                        마지막 축제 (Live)  서태지와 아이들
# 12                              발해를 꿈꾸며  서태지와 아이들
# 13                                   영원  서태지와 아이들
# 14                               교실 이데아  서태지와 아이들
# 15                       널 지우려 해 (Live)  서태지와 아이들
# 16                       Come Back Home  서태지와 아이들
# 17                                슬픈 아픔  서태지와 아이들
# ...

# %%
# null이 아닌 행만을 따로 저장
# df = song[pd.notnull(song['lyrics'])]
# df = song[pd.notnull(song['artist'])]

# %%
song['creator'] = song['creator'].str.replace(r'\r\r\r\n', ' ')

# %%
song['creator'] = song['creator'].str.replace(r'\r\r\r', ' ')

# %%
song
# Out:
#                                   title    artist  \
# 0                                태지 보이스  서태지와 아이들
# 1                            시대유감(時代遺憾)  서태지와 아이들
# 2                              수시아(誰是我)  서태지와 아이들
# 3                   이 밤이 깊어 가지만 (Remix)  서태지와 아이들
# 4                            Free Style  서태지와 아이들
# 5                                 난 알아요  서태지와 아이들
# 6                          너와 함께한 시간속에서  서태지와 아이들
# 7                               환상속의 그대  서태지와 아이들
# 8                                   하여가  서태지와 아이들
# 9                                   너에게  서태지와 아이들
# 10                             우리들만의 추억  서태지와 아이들
# 11                        마지막 축제 (Live)  서태지와 아이들
# 12                              발해를 꿈꾸며  서태지와 아이들
# 13                                   영원  서태지와 아이들
# 14                               교실 이데아  서태지와 아이들
# 15                       널 지우려 해 (Live)  서태지와 아이들
# 16                       Come Back Home  서태지와 아이들
# 17                                슬픈 아픔  서태지와 아이들
# ...

# %%
test = "서태지 작사 김종서 작사 서태지 작곡 김종서 작곡 서태지 편곡"

# %%
test.split(' ')
# Out:
# ['서태지', '작사', '김종서', '작사', '서태지', '작곡', '김종서', '작곡', '서태지', '편곡']
