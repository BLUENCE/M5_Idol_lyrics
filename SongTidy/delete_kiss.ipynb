# %%
import pandas as pd

# %%
song= pd.read_csv("M5_Idol_lyrics/Data/song_data_yewon_ver04.csv")

# %%
song[song['artist'] == '키스']
# Out:
#                          title artist      album release_date song_genre  \
# 2866                    Unholy     키스  Alive III   1993.04.30       Rock
# 2867                    Domino     키스  Alive III   1993.04.30       Rock
# 2868               Take It Off     키스  Alive III   1993.04.30       Rock
# 2869                Tough Love     키스    Revenge   1992.05.18       Rock
# 2870                      Spit     키스    Revenge   1992.05.18       Rock
# 2871           Heart Of Chrome     키스    Revenge   1992.05.18       Rock
# 2872  Every Time I Look At You     키스    Revenge   1992.05.18       Rock
# 2873                 Paralyzed     키스    Revenge   1992.05.18       Rock
#
#      is_title like                                             lyrics  \
# 2866     인기 곡    0  I was there through the ages<br>Chained slaves...
# 2867     인기 곡    0  Now lemme tell ya my story,<br>I got a man-siz...
# 2868      수록곡    0  Well my mind is gettin' dirty yeah<br>around e...
# ...

# %%
song = song[song['artist'] != '키스']

# %%
song.reset_index(inplace=False)
song.head()
# Out:
#         title    artist                                 album release_date  \
# 0      태지 보이스  서태지와 아이들                            시대유감(時代遺憾)   1996.06.07
# 1  시대유감(時代遺憾)  서태지와 아이들                            시대유감(時代遺憾)   1996.06.07
# 2    수시아(誰是我)  서태지와 아이들                            시대유감(時代遺憾)   1996.06.07
# 3  Free Style  서태지와 아이들                            시대유감(時代遺憾)   1996.06.07
# 4       난 알아요  서태지와 아이들  Seotaji And Boys Good Bye Best Album   1996.02.10
#
#   song_genre is_title   like  \
# 0       Rock      수록곡    269
# 1       Rock    타이틀 곡  3,256
# 2       Rock      수록곡    488
# 3       Rock      수록곡    599
# 4      Dance    타이틀 곡    620
#
#                                               lyrics            lyricist  \
# 0  갈수 없는 곳이란 우리에겐 없어<br>보이는 길밖에도 세상은 있어<br>언제나 식지...              서태지
# 1  왜 기다려 왔잖아<br>모든 삶을 포기하는 소리를<br>이 세상이 모두 미쳐버릴<b...              서태지
# 2  이 세상 그 누구도 나를 닮을 순 없네<br>날 세상에 알릴 거야<br>나 역시 그...              서태지
# ...

# %%
song[song['artist'] == '키스']
# Out:
# Empty DataFrame
# Columns: [title, artist, album, release_date, song_genre, is_title, like, lyrics, lyricist, composer, arranger]
# Index: []

# %%
song.to_csv('song_data_yewon_ver05.csv')
