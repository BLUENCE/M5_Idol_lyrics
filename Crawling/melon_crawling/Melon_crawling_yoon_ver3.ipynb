# %%
# !pip install html5lib beautifulsoup4
# !pip install selenium

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
from time import sleep
import requests
import json
import re
from urllib import request
from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.common.keys import Keys

# %%
#path=r"C:\Users\Kavin\Downloads\chromedriver_win32\chromedriver"
path=r'../shoppingmall/chromedriver'
driver=webdriver.Chrome(path)
driver.get("https://www.melon.com/artist/song.htm?artistId=780066")

# %%
title = []
album = []
# release_date = []
# song_genre = []
# like = []
# lyrics = []
# creator = []
# artist = []
# artist_m = []
# debut_y = []
# debut_t = []
# agency = []

# %%
def list_clear():
    title.clear()
    album.clear()
#     release_date.clear()
#     song_genre.clear()
#     like.clear()
#     lyrics.clear()
#     creator.clear()
#     artist.clear()
#     artist_m.clear()
#     debut_y.clear()
#     debut_t.clear()
#     agency.clear()

# %%
def click_artist():
    driver.find_element_by_xpath('//*[@id="conts"]/div[3]/div[1]/div[1]/div/a/strong').click()
    artist.append(driver.find_element_by_xpath('//*[@id="conts"]/div[1]/div/div[2]/p').text)
    artist_m.append(driver.find_element_by_xpath('//*[@id="conts"]/div[1]/div/div[2]/div').text)
    debut_y.append(driver.find_element_by_xpath('//*[@id="conts"]/div[1]/div/div[2]/dl[1]/dd[1]').text)
    debut_t.append(driver.find_element_by_xpath('//*[@id="conts"]/div[1]/div/div[2]/dl[1]/dd[1]/a/span[2]').text)
    agency.append(driver.find_element_by_xpath('//*[@id="conts"]/div[1]/div/div[2]/dl[1]/dd[3]').text)

# %%
def append_list():
    title.append(driver.find_element_by_xpath('//*[@id="downloadfrm"]/div/div/div[2]/div[1]/div[1]').text)
    album.append(driver.find_element_by_xpath('//*[@id="downloadfrm"]/div/div/div[2]/div[2]/dl/dd[1]/a').text)
    release_date.append(driver.find_element_by_xpath('//*[@id="downloadfrm"]/div/div/div[2]/div[2]/dl/dd[2]').text)
    song_genre.append(driver.find_element_by_xpath('//*[@id="downloadfrm"]/div/div/div[2]/div[2]/dl/dd[3]').text)
    like.append(driver.find_element_by_xpath('//*[@id="d_like_count"]').text)
    try:
        lyrics.append(driver.find_element_by_xpath('//*[@id="d_video_summary"]').text)
    except NoSuchElementException as e:
        lyrics.append('')
    # 작곡/작사 없는 경우 예외 처리
    try:
        creator.append(driver.find_element_by_xpath('//*[@id="conts"]/div[3]/ul').text)
    except NoSuchElementException as e:
        creator.append('')

# %%
def get_page_num():
    soup.find_all("a", class_="sister")

# %%
# search = driver.find_element_by_xpath("//*[@id='top_search']")
# search.send_keys(Keys.CONTROL + "a");
# search.clear()
# WebDriverWait(driver, timeout)
# search.send_keys("레드벨벳")

list_clear()
# # 아티스트명 검색
# search.send_keys(Keys.RETURN)

# click_artist()

# # 곡 클릭
# driver.find_element_by_xpath('//*[@id="conts"]/div[3]/ul/li[3]/a').click()
# a = []
# bs4.findAll("", {"class":"page_num"})
index = 1
while True:

    link1 = '//*[@id="frm"]/div/table/tbody/tr['
    link2 = ']/td[3]/div/div/a[1]/span'
    link3 = ']/td[3]/div/div/a/span'
    # 곡 정보 클릭
    print(index)
    try:
        driver.find_element_by_xpath(link1 +str(index)+ link2).click()
    except NoSuchElementException as e:
        driver.find_element_by_xpath(link1 +str(index)+ link3).click()
    append_list()
    
    print(len(title), title[len(title)-1])
    
    # 뒤로가기 누르기
    driver.execute_script("window.history.go(-1)")
    
    index += 1
        
    if len(title)%50 == 0:
        sleep(5)
        driver.find_element_by_xpath('//*[@id="pageObjNavgation"]/div/a[4]').click()
        index = 1
        sleep(5)
        continue
        
        
#     # 마지막 페이지인 경우 while문을 빠져나감    
#     next_link_end = driver.find_element_by_xpath('//*[@id="pageObjNavgation"]/div/a')
#     hi = next_link_end.get_attribute('class')
#     if hi == 'btn_next disabled':
#         print('마지막 페이지입니다')
#         break
# Out:
# 1
# 1 Power Up
# 2
# 2 한 여름의 크리스마스 (With You)
# 3
# 3 Mr. E
# 4
# 4 Mosquito
# 5
# 5 Hit That Drum
# 6
# 6 Blue Lemonade
# 7
# 7 (Bonus Track) Bad Boy (English Ver.)
# 8
# 8 #Cookie Jar
# 9
# 9 Aitai-tai
# 10
# 10 `Cause it`s you
# 11
# 11 Dumb Dumb
# 12
# 12 Russian Roulette
# 13
# 13 Red Flavor
# 14
# 14 떠날 거야
# 15
# 15 Bad Boy
# 16
# 16 All Right
# 17
# 17 피카부 (Peek-A-Boo)
# 18
# 18 봐 (Look)
# 19
# 19 I Just
# 20
# 20 Kingdom Come
# 21
# 21 Time To Love
# 22
# 22 두 번째 데이트 (My Second Date)
# 23
# 23 Attaboy
# 24
# 24 Perfect 10
# 25
# 25 About Love
# 26
# 26 달빛 소리 (Moonlight Melody)
# 27
# 27 피카부 (Peek-A-Boo)
# 28
# 28 봐 (Look)
# 29
# 29 I Just
# 30
# 30 Kingdom Come
# 31
# 31 두 번째 데이트 (My Second Date)
# 32
# 32 Attaboy
# 33
# 33 Perfect 10
# 34
# 34 About Love
# 35
# 35 달빛 소리 (Moonlight Melody)
# 36
# 36 환생 (Rebirth)
# 37
# 37 환생 (Rebirth) (Inst.)
# 38
# 38 빨간 맛 (Red Flavor)
# 39
# 39 You Better Know
# 40
# 40 Zoo
# 41
# 41 여름빛 (Mojito)
# 42
# 42 바다가 들려 (Hear The Sea)
# 43
# 43 Would U
# 44
# 44 Would U (Inst.)
# 45
# 45 Rookie
# 46
# 46 Little Little
# 47
# 47 Happily Ever After
# 48
# 48 Talk To Me
# 49
# 49 Body Talk
# 50
# 50 마지막 사랑 (Last Love)
# 1
# 51 러시안 룰렛 (Russian Roulette)
# 2
# 52 Lucky Girl
# 3
# 53 Bad Dracula
# 4
# 54 Sunny Afternoon
# 5
# 55 Fool
# 6
# 56 Some Love
# 7
# 57 My Dear
# 8
# 58 여시주의
# 9
# 59 7월 7일 (One Of These Nights)
# 10
# 60 Cool Hot Sweet Love
# 11
# 61 Light Me Up
# 12
# 62 처음인가요 (First Time)
# 13
# 63 장미꽃 향기는 바람에 날리고 (Rose Scent Breeze)
# 14
# 64 7월 7일 (One Of These Nights) (De-Capo Ver.)
# 15
# 65 7월 7일 (One Of These Nights) (Joe Millionaire Ver.)
# 16
# 66 7월 7일 (One Of These Nights) (Piano Ver.)
# 17
# 67 너에게 원한건
# 18
# 68 세가지 소원 (Wish Tree)
# 19
# 69 Dumb Dumb
# 20
# 70 Huff n Puff
# 21
# 71 Campfire
# 22
# 72 Red Dress
# 23
# 73 Oh Boy
# 24
# 74 Lady`s Room
# 25
# 75 Time Slip
# 26
# 76 Don`t U Wait No More
# 27
# 77 Day 1
# 28
# 78 Cool World
# 29
# 79 Automatic
# 30
# 80 Ice Cream Cake
# 31
# 81 Somethin Kinda Crazy
# 32
# 82 Stupid Cupid
# 33
# 83 Take It Slow
# 34
# 84 사탕 (Candy)
# 35
# 85 Be Natural (Feat. SR14B `TAEYONG (태용)`)
# 36
# 86 행복 (Happiness)
# 37
# 87 안녕
# 38
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-48-812872693a64> in <module>()
#      25     try:
# ---> 26         driver.find_element_by_xpath(link1 +str(index)+ link2).click()
#      27     except NoSuchElementException as e:
#
# ~/anaconda3/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in find_element_by_xpath(self, xpath)
#     392         """
# --> 393         return self.find_element(by=By.XPATH, value=xpath)
#     394
#
# ~/anaconda3/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in find_element(self, by, value)
#     965             'using': by,
# --> 966             'value': value})['value']
#     967
#
# ~/anaconda3/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         if response:
# --> 320             self.error_handler.check_response(response)
#     321             response['value'] = self._unwrap_value(
#
# ~/anaconda3/lib/python3.6/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="frm"]/div/table/tbody/tr[38]/td[3]/div/div/a[1]/span"}
#   (Session info: chrome=69.0.3497.81)
#   (Driver info: chromedriver=2.41.578706 (5f725d1b4f0a4acbf5259df887244095596231db),platform=Mac OS X 10.11.6 x86_64)
#
#
# During handling of the above exception, another exception occurred:
#
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-48-812872693a64> in <module>()
#      26         driver.find_element_by_xpath(link1 +str(index)+ link2).click()
#      27     except NoSuchElementException as e:
# ---> 28         driver.find_element_by_xpath(link1 +str(index)+ link3).click()
#      29     append_list()
#      30
#
# ~/anaconda3/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in find_element_by_xpath(self, xpath)
#     391             element = driver.find_element_by_xpath('//div/td[1]')
#     392         """
# --> 393         return self.find_element(by=By.XPATH, value=xpath)
#     394
#     395     def find_elements_by_xpath(self, xpath):
#
# ~/anaconda3/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in find_element(self, by, value)
#     964         return self.execute(Command.FIND_ELEMENT, {
#     965             'using': by,
# --> 966             'value': value})['value']
#     967
#     968     def find_elements(self, by=By.ID, value=None):
#
# ~/anaconda3/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     318         response = self.command_executor.execute(driver_command, params)
#     319         if response:
# --> 320             self.error_handler.check_response(response)
#     321             response['value'] = self._unwrap_value(
#     322                 response.get('value', None))
#
# ~/anaconda3/lib/python3.6/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="frm"]/div/table/tbody/tr[38]/td[3]/div/div/a/span"}
#   (Session info: chrome=69.0.3497.81)
#   (Driver info: chromedriver=2.41.578706 (5f725d1b4f0a4acbf5259df887244095596231db),platform=Mac OS X 10.11.6 x86_64)
